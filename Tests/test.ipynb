# %%
# %matplotlib inline 
import sys
sys.path.append("..")
import dataReader

dr = dataReader.DataReader(dataFolder='../Data')
# Out:
# Opening visualizer
# Read in Point Cloud object ../Data\Cloud Sample Data\1608332814003
# Face shape:  (39877, 3)
# All shape:  (235551, 3)
# Downsampled Face shape:  (1000, 3)
# Downsampled All shape:  (1000, 3)
# Opening visualizer
# Read in Point Cloud object ../Data\Cloud Sample Data\1608335007385
# Face shape:  (43676, 3)
# All shape:  (184180, 3)
# Downsampled Face shape:  (1000, 3)
# Downsampled All shape:  (1000, 3)
# Opening visualizer
# Read in Point Cloud object ../Data\Cloud Sample Data\1608337821692
# Face shape:  (45513, 3)
# All shape:  (255571, 3)
# Downsampled Face shape:  (1000, 3)
# Downsampled All shape:  (1000, 3)
# Opening visualizer
# Read in Point Cloud object ../Data\Cloud Sample Data\1608340797805
# Face shape:  (43242, 3)
# All shape:  (306368, 3)
# Downsampled Face shape:  (1000, 3)
# Downsampled All shape:  (1000, 3)
# Opening visualizer
# Read in Point Cloud object ../Data\Cloud Sample Data\1608343408802
# Face shape:  (63339, 3)
# ...
